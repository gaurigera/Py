# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('datasets/UNSW_NB15.csv')

# %%
data.head()
# Out:
#    id       dur proto service state  spkts  dpkts  sbytes  dbytes       rate  \
# 0   1  0.121478   tcp       -   FIN      6      4     258     172  74.087490
# 1   2  0.649902   tcp       -   FIN     14     38     734   42014  78.473372
# 2   3  1.623129   tcp       -   FIN      8     16     364   13186  14.170161
# 3   4  1.681642   tcp     ftp   FIN     12     12     628     770  13.677108
# 4   5  0.449454   tcp       -   FIN     10      6     534     268  33.373826
#
#    ...  ct_dst_sport_ltm  ct_dst_src_ltm  is_ftp_login  ct_ftp_cmd  \
# 0  ...                 1               1             0           0
# 1  ...                 1               2             0           0
# 2  ...                 1               3             0           0
# 3  ...                 1               3             1           1
# 4  ...                 1              40             0           0
#
#    ct_flw_http_mthd  ct_src_ltm  ct_srv_dst  is_sm_ips_ports  attack_cat  \
# ...

# %%
data[data['service']=='-']
# Out:
#             id       dur proto service state  spkts  dpkts  sbytes  dbytes  \
# 0            1  0.121478   tcp       -   FIN      6      4     258     172
# 1            2  0.649902   tcp       -   FIN     14     38     734   42014
# 2            3  1.623129   tcp       -   FIN      8     16     364   13186
# 4            5  0.449454   tcp       -   FIN     10      6     534     268
# 5            6  0.380537   tcp       -   FIN     10      6     534     268
# ...        ...       ...   ...     ...   ...    ...    ...     ...     ...
# 175125  175126  0.653375   tcp       -   FIN     10      8     564     354
# 175179  175180  0.695566   tcp       -   FIN     10      8     564     354
# 175191  175192  0.962856   tcp       -   FIN     24     60    1256   59374
# 175277  175278  3.719110   tcp       -   FIN     66    340    3086  426483
# 175337  175338  0.505762   tcp       -   FIN     10      8     620     354
#
# ...

# %%
data['service'].replace('-',np.nan,inplace=True)

# %%
data.isnull().sum()
# Out:
# id                       0
# dur                      0
# proto                    0
# service              94168
# state                    0
# spkts                    0
# dpkts                    0
# sbytes                   0
# dbytes                   0
# rate                     0
# sttl                     0
# dttl                     0
# sload                    0
# dload                    0
# sloss                    0
# dloss                    0
# sinpkt                   0
# dinpkt                   0
# sjit                     0
# djit                     0
# swin                     0
# stcpb                    0
# dtcpb                    0
# dwin                     0
# tcprtt                   0
# synack                   0
# ackdat                   0
# smean                    0
# dmean                    0
# trans_depth              0
# response_body_len        0
# ct_srv_src               0
# ct_state_ttl             0
# ct_dst_ltm               0
# ...

# %%
data.dropna(inplace=True)

# %%
data['attack_cat'].value_counts()
# Out:
# Generic           39496
# Normal            19488
# Exploits          16187
# DoS                1791
# Fuzzers            1731
# Reconnaissance     1703
# Analysis            564
# Worms               114
# Backdoor             99
# Name: attack_cat, dtype: int64

# %%
data['state'].value_counts()
# Out:
# INT    39580
# FIN    33640
# CON     7711
# REQ      228
# RST       14
# Name: state, dtype: int64

# %%
data
# Out:
#             id       dur proto service state  spkts  dpkts  sbytes  dbytes  \
# 3            4  1.681642   tcp     ftp   FIN     12     12     628     770
# 11          12  2.093085   tcp    smtp   FIN     62     28   56329    2212
# 15          16  0.000002   udp    snmp   INT      2      0     138       0
# 17          18  0.393556   tcp    http   FIN     10      8     860    1096
# 21          22  0.338017   tcp    http   FIN     10      6     998     268
# ...        ...       ...   ...     ...   ...    ...    ...     ...     ...
# 175335  175336  0.000006   udp     dns   INT      2      0     114       0
# 175336  175337  0.000009   udp     dns   INT      2      0     114       0
# 175338  175339  0.000009   udp     dns   INT      2      0     114       0
# 175339  175340  0.000009   udp     dns   INT      2      0     114       0
# 175340  175341  0.000009   udp     dns   INT      2      0     114       0
#
# ...

# %%
data_features=pd.read_csv('datasets\\UNSW_NB15_features.csv')

# %%
data_features.head()
# Out:
#    No.    Name    Type               Description
# 0    1   srcip  nominal        Source IP address
# 1    2   sport  integer       Source port number
# 2    3   dstip  nominal   Destination IP address
# 3    4  dsport  integer  Destination port number
# 4    5   proto  nominal     Transaction protocol

# %%
data_features['Type ']=data_features['Type '].str.lower()

# %%
nominal_names=data_features['Name'][data_features['Type ']=='nominal']
float_names=data_features['Name'][data_features['Type ']=='float']
integer_names=data_features['Name'][data_features['Type ']=='integer']
binary_names=data_features['Name'][data_features['Type ']=='binary']

# %%
binary_names=data.columns.intersection(binary_names)
float_names=data.columns.intersection(float_names)
integer_names=data.columns.intersection(integer_names)

# %%
for c in binary_names:
    pd.to_numeric(data[c])
for c in float_names:
    pd.to_numeric(data[c])
for c in integer_names:
    pd.to_numeric(data[c])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 81173 entries, 3 to 175340
# Data columns (total 45 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 81173 non-null  int64
#  1   dur                81173 non-null  float64
#  2   proto              81173 non-null  object
#  3   service            81173 non-null  object
#  4   state              81173 non-null  object
#  5   spkts              81173 non-null  int64
#  6   dpkts              81173 non-null  int64
#  7   sbytes             81173 non-null  int64
#  8   dbytes             81173 non-null  int64
#  9   rate               81173 non-null  float64
#  10  sttl               81173 non-null  int64
#  11  dttl               81173 non-null  int64
#  12  sload              81173 non-null  float64
#  13  dload              81173 non-null  float64
#  14  sloss              81173 non-null  int64
#  15  dloss              81173 non-null  int64
# ...

# %% [markdown]
# # Data Visualization

# %%
import matplotlib.pyplot as plt

# %%
data
# Out:
#             id       dur proto service state  spkts  dpkts  sbytes  dbytes  \
# 3            4  1.681642   tcp     ftp   FIN     12     12     628     770
# 11          12  2.093085   tcp    smtp   FIN     62     28   56329    2212
# 15          16  0.000002   udp    snmp   INT      2      0     138       0
# 17          18  0.393556   tcp    http   FIN     10      8     860    1096
# 21          22  0.338017   tcp    http   FIN     10      6     998     268
# ...        ...       ...   ...     ...   ...    ...    ...     ...     ...
# 175335  175336  0.000006   udp     dns   INT      2      0     114       0
# 175336  175337  0.000009   udp     dns   INT      2      0     114       0
# 175338  175339  0.000009   udp     dns   INT      2      0     114       0
# 175339  175340  0.000009   udp     dns   INT      2      0     114       0
# 175340  175341  0.000009   udp     dns   INT      2      0     114       0
#
# ...

# %% [markdown]
# **Binary**

# %%
plt.figure(figsize=(5,5))
plt.pie(data.label.value_counts(),labels=['normal','abnormal'],autopct='%0.2f%%')
plt.legend()
plt.show()

# %% [markdown]
# **Multi-class**

# %%
plt.pie(data.attack_cat.value_counts(),labels=data.attack_cat.unique(),autopct='%0.2f%%',radius=3.0,hatch=['**','//','||','\\','##'])
plt.legend(loc='best')
plt.show()
# Out:
# C:\Users\gauri\AppData\Local\Temp\ipykernel_17728\595173827.py:1: MatplotlibDeprecationWarning: hatch must consist of a string of "*+-./OX\ox|" or None, but found the following invalid values "#". Passing invalid values is deprecated since 3.4 and will become an error in 3.8.
#   plt.pie(data.attack_cat.value_counts(),labels=data.attack_cat.unique(),autopct='%0.2f%%',radius=3.0,hatch=['**','//','||','\\','##'])

# %% [markdown]
# # One Hot Encoding

# %%
num_cols=data.select_dtypes(include='number').columns

cat_cols=data.columns.difference(num_cols)
cat_cols=cat_cols[1:]

# %%
cat_cols #All the columns without any numeric data
# Out:
# Index(['proto', 'service', 'state'], dtype='object')

# %%
##Creating a dataframe with only the categorical data
data_cat=data[cat_cols].copy()
data_cat.head()
# Out:
#    proto service state
# 3    tcp     ftp   FIN
# 11   tcp    smtp   FIN
# 15   udp    snmp   INT
# 17   tcp    http   FIN
# 21   tcp    http   FIN

# %%
data_cat = pd.get_dummies(data_cat,columns=cat_cols)

# %%
data_cat.head()
# Out:
#     proto_tcp  proto_udp  service_dhcp  service_dns  service_ftp  \
# 3           1          0             0            0            1
# 11          1          0             0            0            0
# 15          0          1             0            0            0
# 17          1          0             0            0            0
# 21          1          0             0            0            0
#
#     service_ftp-data  service_http  service_irc  service_pop3  service_radius  \
# 3                  0             0            0             0               0
# 11                 0             0            0             0               0
# 15                 0             0            0             0               0
# 17                 0             1            0             0               0
# 21                 0             1            0             0               0
#
#     service_smtp  service_snmp  service_ssh  service_ssl  state_CON  \
# ...

# %%
data=pd.concat([data,data_cat],axis=1)
data.head()
# Out:
#     id       dur proto service state  spkts  dpkts  sbytes  dbytes  \
# 3    4  1.681642   tcp     ftp   FIN     12     12     628     770
# 11  12  2.093085   tcp    smtp   FIN     62     28   56329    2212
# 15  16  0.000002   udp    snmp   INT      2      0     138       0
# 17  18  0.393556   tcp    http   FIN     10      8     860    1096
# 21  22  0.338017   tcp    http   FIN     10      6     998     268
#
#              rate  ...  service_radius  service_smtp  service_snmp  \
# 3       13.677108  ...               0             0             0
# 11      42.520967  ...               0             1             0
# 15  500000.001300  ...               0             0             1
# 17      43.195886  ...               0             0             0
# 21      44.376468  ...               0             0             0
#
#     service_ssh  service_ssl  state_CON  state_FIN  state_INT  state_REQ  \
# 3             0            0          0          1          0          0
# ...

# %%
data.drop(columns=cat_cols,inplace=True)

# %% [markdown]
# # Data Normalization

# %%
num_col=list(data.select_dtypes(include="number").columns)
num_col.remove('id')
num_col.remove('label')

# %%
from sklearn.preprocessing import MinMaxScaler
# using minmax scaler for normalizing data
minmax_scale = MinMaxScaler()
def normalization(df,col):
  for i in col:
    arr = df[i]
    arr = np.array(arr)
    df[i] = minmax_scale.fit_transform(arr.reshape(len(arr),1))
  return df

# %%
normalization(data,num_col)
data.head()
# Out:
#     id           dur     spkts     dpkts    sbytes    dbytes      rate  \
# 3    4  2.802780e-02  0.001144  0.001093  0.000041  0.000053  0.000014
# 11  12  3.488529e-02  0.006344  0.002551  0.004337  0.000151  0.000043
# 15  16  1.666693e-08  0.000104  0.000000  0.000003  0.000000  0.500000
# 17  18  6.559354e-03  0.000936  0.000729  0.000059  0.000075  0.000043
# 21  22  5.633690e-03  0.000936  0.000547  0.000069  0.000018  0.000044
#
#         sttl      dttl     sload  ...  service_radius  service_smtp  \
# 3   0.138393  0.992126  0.000001  ...             0.0           0.0
# 11  0.138393  0.992126  0.000092  ...             0.0           1.0
# 15  0.995536  0.000000  0.119792  ...             0.0           0.0
# 17  0.138393  0.992126  0.000007  ...             0.0           0.0
# 21  0.995536  0.992126  0.000009  ...             0.0           0.0
#
#     service_snmp  service_ssh  service_ssl  state_CON  state_FIN  state_INT  \
# ...

# %% [markdown]
# # Label Encoding

# %% [markdown]
# **Binary Labels**

# %%
#Changing attack labels (normal and abnormal instead of 0 and 1)
bin_label = pd.DataFrame(data.label.map(lambda x: 'normal' if x==0 else 'abnormal'))

# %%
bin_data= data.copy()
bin_data['label']=bin_label

# %%
from sklearn import preprocessing


le1= preprocessing.LabelEncoder()
encode_label=bin_label.apply(le1.fit_transform)
bin_data['label']=encode_label

# %%
le1.classes_ #Distinct classes encountered
# Out:
# array(['abnormal', 'normal'], dtype=object)

# %%
np.save("le1_classes.npy", le1.classes_ ,allow_pickle=True)

# %% [markdown]
# # Multi-Class Labels

# %%
multi_label=pd.DataFrame(data.attack_cat)
multi_data=data.copy()

# %%
encode_label=multi_label.apply(le1.fit_transform)
multi_data['label']=encode_label

# %%
le1.classes_
# Out:
# array(['Analysis', 'Backdoor', 'DoS', 'Exploits', 'Fuzzers', 'Generic',
#        'Normal', 'Reconnaissance', 'Worms'], dtype=object)

# %%
np.save("le2_classes",le1.classes_,allow_pickle=True)

# %%
num_col.append('label') #Done as we want to include 'label' while checking the correlation

# %% [markdown]
# # Checking the correlation

# %% [markdown]
# **Bin Corr using Correlation matrix**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(10,8))
bin_corr = bin_data[num_col].corr()
sns.heatmap(bin_corr)
plt.show()

# %% [markdown]
# **Multi Corr using correlation matrix**

# %%
plt.figure(figsize=(10,8))
multi_corr = bin_data[num_col].corr()
sns.heatmap(multi_corr)
plt.show()

# %%
temp=3
while(temp):
    print(temp)
    temp=temp-1
# Out:
# 3
# 2
# 1
